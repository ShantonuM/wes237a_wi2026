# %%
import socket

# %% [markdown]
# Sending to my laptop being the server

# %%
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# TODO:
# 1: Connect the socket (sock) to the <SERVER-IP> and choosen port <LISTENING-PORT>

SERVER_IP = "192.168.8.149"
LISTENING_PORT = 12345

sock.connect((SERVER_IP, LISTENING_PORT))

# 2: Send the message "Hello world!\n"
try:[[[[[[[[[5]]]]]]]]]
    sock.sendall(b'Hello world!\n')
except:
    sock.close()

# 3: Close the socket
sock.close()

# %%
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# TODO:
# 1: Connect the socket (sock) to the <SERVER-IP> and choosen port <LISTENING-PORT>

SERVER_IP = "192.168.8.149"
LISTENING_PORT = 12345

sock.connect((SERVER_IP, LISTENING_PORT))

# 2: Send the message "Hello world!\n"
try:
    sock.sendall(b'Hola!\n')
except:
    sock.close()

# 3: Close the socket
sock.close()
